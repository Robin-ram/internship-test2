# %%
pip install pandas

# %%
import pandas as pd
ram = pd.read_csv("/content/main.csv")
ram.head()
# Out:
#    product_code product_description product_group  sales_date  price  \
# 0          1001              tomato     vegetable  2021-11-01   2.99
# 1          1001              tomato     vegetable  2021-11-02   2.99
# 2          1001              tomato     vegetable  2021-11-03   2.99
# 3          1001              tomato     vegetable  2021-11-04   2.99
# 4          1001              tomato     vegetable  2021-11-05   2.99
#
#    sales_quantity unit
# 0              36   kg
# 1              23   kg
# 2              34   kg
# 3              23   kg
# 4              34   kg

# %%
ram.groupby('product_description')['price'].mean()
# Out:
# product_description
# apple           2.077778
# butter-0.25    11.400000
# cucumber        4.532857
# grape           4.400000
# milk-1.5        6.078571
# onion           2.150714
# orange          2.714286
# plum            4.389655
# tomato          3.121034
# yogurt-1        6.693103
# Name: price, dtype: float64

# %%
ram["price_new"] = ram['price']
(
   ram.groupby('product_description')['price'].transform("mean")
)
ram[ram["price"].isna()].head()
# Out:
#     product_code product_description product_group  sales_date  price  \
# 10          1001              tomato     vegetable  2021-11-11    NaN
# 34          1002            cucumber     vegetable  2021-11-05    NaN
# 37          1002            cucumber     vegetable  2021-11-08    NaN
# 73          1003               onion     vegetable  2021-11-14    NaN
# 74          1003               onion     vegetable  2021-11-15    NaN
#
#     sales_quantity unit  price_new
# 10              20   kg        NaN
# 34              24   kg        NaN
# 37              38   kg        NaN
# 73              39   kg        NaN
# 74              25   kg        NaN

# %%
ram["price_new"] = ram['price'].fillna(
   ram.groupby('product_description')['price'].transform("mean")
)

# %%
ram[ram["price"].isna()].head()
# Out:
#     product_code product_description product_group  sales_date  price  \
# 10          1001              tomato     vegetable  2021-11-11    NaN
# 34          1002            cucumber     vegetable  2021-11-05    NaN
# 37          1002            cucumber     vegetable  2021-11-08    NaN
# 73          1003               onion     vegetable  2021-11-14    NaN
# 74          1003               onion     vegetable  2021-11-15    NaN
#
#     sales_quantity unit  price_new
# 10              20   kg   3.121034
# 34              24   kg   4.532857
# 37              38   kg   4.532857
# 73              39   kg   2.150714
# 74              25   kg   2.150714
